# %%
#Importing Libraries 
import matplotlib.pyplot as plt 
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import learning_curve

# %%
np.random.seed(42)
m = 100
X = 6 * np.random.rand(m,1) * 100
y = 0.5 * X ** 2 + X + 2 + np.random.randn(m,2)

# %%
train_sizes, train_scores, valid_scores = learning_curve(
    estimator=LinearRegression(),
    X=X,
    y=y,
    train_sizes=np.linspace(0.01, 1.0, 40),
    cv=5,
    scoring="neg_root_mean_squared_error"
)
train_errors = -train_scores.mean(axis = 1)
valid_errors = -valid_scores.mean(axis = 1)

plt.plot(train_sizes,train_errors, "r-+",linewidth =2, label ="train")
plt.plot(train_sizes,valid_errors,"b-",linewidth = 3, label = "valid")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 train_sizes,train_scores,valid_scores = learning_curve(LinearRegression(),X,y, np.linspace(0.01,1.0,40),cv = 5,scoring="neg_root_mean_squared_error")
#       2 train_errors = -train_scores.mean(axis = 1)
#       3 valid_errors = -valid_scores.mean(axis = 1)
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File /opt/anaconda3/lib/python3.13/inspect.py:3295, in Signature.bind(self, *args, **kwargs)
#    3290 def bind(self, /, *args, **kwargs):
#    3291     """Get a BoundArguments object, that maps the passed `args`
#    3292     and `kwargs` to the function's signature.  Raises `TypeError`
#    3293     if the passed arguments can not be bound.
#    3294     """
# -> 3295     return self._bind(args, kwargs)
#
# File /opt/anaconda3/lib/python3.13/inspect.py:3219, in Signature._bind(self, args, kwargs, partial)
#    3215 else:
#    3216     if param.kind in (_VAR_KEYWORD, _KEYWORD_ONLY):
#    3217         # Looks like we have no parameter for this positional
#    3218         # argument
# -> 3219         raise TypeError(
#    3220             'too many positional arguments') from None
#    3222     if param.kind == _VAR_POSITIONAL:
#    3223         # We have an '*args'-like argument, let's fill it with
#    3224         # all positional arguments we have left and move on to
#    3225         # the next phase
#    3226         values = [arg_val]
#
# TypeError: too many positional arguments
