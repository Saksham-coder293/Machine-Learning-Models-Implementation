# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

iris = load_iris(as_frame = True)
X_iris = iris.data[["petal length (cm)", "petal width (cm)"]].values
y_iris = iris.target

tree_clf = DecisionTreeClassifier()
tree_clf.fit(X_iris, y_iris)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import export_graphviz

export_graphviz(
    tree_clf,
    out_file = "iris.tree.dot",
    feature_names = ["petal length (cm)","petal width (cm)"],
    class_names = iris.target_names,
    rounded = True,
    filled = True
)

# %%
# %pip install graphviz

import graphviz

# Now you can use it
dot = graphviz.Digraph()
dot.node('A', 'Node A')
dot.node('B', 'Node B')
dot.edge('A', 'B')
dot.view()  # This will render and open the graph
# Out:
# Requirement already satisfied: graphviz in /opt/anaconda3/lib/python3.13/site-packages (0.21)
# Note: you may need to restart the kernel to use updated packages.
# 'Digraph.gv.pdf'

# %%
from graphviz import Source
Source.from_file("iris.tree.dot")

# %%
from sklearn.datasets import make_moons
X_moons,y_moons = make_moons(n_samples = 150,noise = 0.2,random_state = 42)

tree_clf1 = DecisionTreeClassifier(random_state = 42)
tree_clf2 =  DecisionTreeClassifier(random_state = 42)
tree_clf1.fit(X_moons, y_moons)
tree_clf2.fit(X_moons, y_moons)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
X_moons_test, y_moons_test = make_moons(n_samples =1000, noise = 0.2, random_state = 42)
tree_clf1.score(X_moons_test, y_moons_test)
tree_clf2.score(X_moons_test,y_moons_test)
# Out:
# 0.901
